# %%
from quotes import QUOTES

# %%
texts = []
labels = []

for q in QUOTES:
    texts.append(q["text"])

    labels.append(q["mood"])

# %%
from sklearn.preprocessing import LabelEncoder


encoder = LabelEncoder()

y = encoder.fit_transform(labels)

# %%
y
# Out:
# array([ 1, 16,  4, 24, 17, 16, 11, 26, 11, 27, 14, 19, 27, 24, 17, 17, 11,
#        24, 15, 13, 13, 26,  2,  4,  4, 17, 27, 23, 15, 19, 27, 26, 26, 13,
#         2, 16, 20, 13, 16, 16, 26, 16, 16, 27,  6, 26, 14,  7,  3, 26,  0,
#         3,  7, 20, 16, 16, 26, 16, 14,  3,  3, 15, 16, 26, 27,  3, 16,  3,
#        27, 27, 26, 26, 26, 26, 26,  5,  8,  0,  3, 20, 27,  8, 26,  2,  3,
#        26,  3, 14, 26, 16, 26, 26,  3, 26,  6, 16,  3, 16, 14, 14,  1,  1,
#         1,  1,  4,  4,  4,  4, 24, 24, 24, 24, 17, 17, 17, 17, 11, 11, 11,
#        11, 27, 27, 27, 27, 14, 14, 14, 14, 19, 19, 19, 19, 15, 15, 15, 15,
#        13, 13, 13, 13,  2,  2,  2,  2, 23, 23, 23, 23, 20, 20, 20, 20,  6,
#         6,  6,  6,  7,  7,  7,  7,  0,  0,  0,  0,  5,  5,  5,  5,  8,  8,
#         8,  8, 21, 21, 21, 21, 12, 12, 12, 12, 22, 22, 22, 22,  9,  9,  9,
#         9, 25, 25, 25, 25, 10, 10, 10, 10, 17, 27, 13,  2, 18, 21, 16, 21,
#        21, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16,
#        18, 12, 22, 18,  9, 25, 18, 10, 12, 18, 12, 22, 18, 12, 18, 25, 22,
#        25, 22, 18, 18, 18, 18, 12,  9, 25, 22, 10, 25])

# %%
encoder.classes_
# Out:
# array(['acceptance', 'awakening', 'compassion', 'devotion', 'fate',
#        'forgiveness', 'freedom', 'grief', 'hope', 'hopeful', 'humorous',
#        'impermanence', 'inspirational', 'joy', 'longing', 'loss', 'love',
#        'mortality', 'motivational', 'mystery', 'peace', 'reflecting',
#        'reflective', 'regret', 'time', 'uplifting', 'wisdom', 'wonder'],
#       dtype='<U13')

# %%
from collections import Counter

moods = [quote["mood"] for quote in QUOTES]

mood_counts = Counter(moods)

for mood, count in mood_counts.items():
    if count < 10:
        print(f"{mood} : {count}")
# Out:
# awakening : 5
# fate : 7
# time : 7
# mortality : 9
# impermanence : 7
# mystery : 6
# loss : 7
# joy : 9
# compassion : 8
# regret : 5
# peace : 7
# freedom : 6
# grief : 6
# acceptance : 6
# forgiveness : 5
# hope : 6
# reflecting : 7
# inspirational : 9
# reflective : 9
# hopeful : 6
# uplifting : 9
# humorous : 6

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DIGIMAHAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DIGIMAHAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords


stop_words = set(stopwords.words('english'))



def preprocess(text):

    tokens = word_tokenize(text.lower())

    tokens = [
        w for w in tokens
        if w.isalpha()
    ]

    tokens = [
        w for w in tokens
        if w not in stop_words
    ]


    return " ".join(tokens)

# %%
clean_texts = []


for t in texts:
    clean_texts.append(
        preprocess(t)
    )

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


vectorizer = TfidfVectorizer()


X = vectorizer.fit_transform(
        clean_texts
)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


vectorizer = TfidfVectorizer()


X = vectorizer.fit_transform(
        clean_texts
)

# %%
print(X.shape)
# Out:
# (250, 1122)

# %%
from sklearn.model_selection import train_test_split


X_train,X_test,y_train,y_test = train_test_split(

X.toarray(),
y,

test_size=0.3
)

# %%
from keras.models import Sequential
from keras.layers import Dense



model = Sequential()

model.add(
Dense(128,
activation='relu',
input_shape=(X_train.shape[1],))
)


model.add(
Dense(64,
activation='relu')
)


model.add(
Dense(
len(set(y)),
activation='softmax'
)
)
# Out:
# c:\Users\DIGIMAHAN\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(

optimizer='adam',

loss='sparse_categorical_crossentropy',

metrics=['accuracy']

)

# %%
model.fit(

X_train,
y_train,

epochs=20,

batch_size=32

)
# Out:
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0171 - loss: 3.3340
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2629 - loss: 3.2969
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4514 - loss: 3.2634
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5143 - loss: 3.2251
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5314 - loss: 3.1788
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5029 - loss: 3.1217
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4857 - loss: 3.0532
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4400 - loss: 2.9651
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3943 - loss: 2.8577
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4057 - loss: 2.7311
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3886 - loss: 2.5796
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3943 - loss: 2.4122
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4286 - loss: 2.2308
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5543 - loss: 2.0433
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6571 - loss: 1.8537
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7257 - loss: 1.6622
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8286 - loss: 1.4712
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8857 - loss: 1.2849
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8914 - loss: 1.1057
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9486 - loss: 0.9394

# %%
loss,acc = model.evaluate(
X_test,
y_test
)

print(acc)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1733 - loss: 3.2917
# 0.1733333319425583
